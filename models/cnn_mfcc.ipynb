# %% [markdown]
# ##### This script will associate spoken phrases with their corresponding translation, using a convolutional neural network ("CNN")
#
# This CNN will rely on all phrases from Female 1 that were spoken more than once, and have a recording using each of the two mics - head and array. The resulting data will have 4 or more records for each prompt. These records will be randomly assigned to train/test by prompt id using a 50/50 split. (e.g. for Female 1, the prompt "chair" was recorded twice in prompt id 46 and 73. In this case the head and array mic recording from prompt id 46 will be used for training, and then head and array mic recordings from prompt id 73 will be used for testing)
#
# In the end, if the CNN can use the phrase spoken in one prompt to predict the same phrase spoken in another prompt, even though it has not used the other prompt to learn, then that should prove this approach works.

# %%
# ##### CNN Parameters #####

batch_size = 10
epochs = 50

image_height_width = 150  # Resize all images to square with this height and width

# AUGMENTATION OPTIONS - Do not use these together! Choose 1 option

# Option 1________________________________________________________________________________________________________________
create_aug_audio = False# Generates more training data by augmenting each training wav file in a handful of ways

# Option 2________________________________________________________________________________________________________________
mean_norm_img = False  # Normalize frequency of all images (training and test set)
blurr_img = False      # Blurr all images with gaussian blur (training and test set)

# Option 3________________________________________________________________________________________________________________
augment_images = False     # Applies random image augmentation on training batches only.

###########################

# %% [markdown]
# ## (1) Load Packages and Functions

# %%
# Load packages

import pandas as pd
import cv2
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf

# import matplotlib.pylab as plt
from skimage import data, img_as_float
from skimage import exposure
import random
import itertools
import librosa
import IPython.display as ipd

# %matplotlib inline

import keras
from keras.datasets import mnist
from keras.layers import Dense, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import BatchNormalization
from keras.models import Sequential

from keras.layers import Activation
from keras.layers import Convolution2D, Dropout
from keras.layers.pooling import GlobalAveragePooling2D
from keras.optimizers import Adamax
from keras.regularizers import l2
from keras import regularizers
from keras.preprocessing.image import ImageDataGenerator

# %%
# ##### FUNCTIONS ##### #

def mean_norm(img):
    """
    A function that takes an image and deducts and divides by the column mean from each point of the array
    to normalize the frequency of each time frame.
    """
    img_mn = (img - (np.mean(img, axis=0) + 1e-8))  # / (np.mean(img, axis=0) + 1e-8)
    return img_mn

def augment_img(img, choose='random'):
    """
    A function that takes a 2D or 3D image and returns a randomly augmented version of the image,
    unless the augmentation type is specified on the call.
    """
    
    img_is_3d = False
    
    # Convert from 3D to 2D e.g. from (56, 56 , 1) to (56, 56)  * if the image came in as 3d
    if img.ndim == 3:
        img = np.squeeze(img)
        img_is_3d = True
    
    # Randomly choose augmentation method, unless specified
    if choose == 'random':
        options = ['AHE','CS','gamma','log','blurr_avg','blurr_gaus','blurr_median','None']
        choose = random.choice(options)
    
    # Adaptive Equalization
    if choose == 'AHE':
        img_new = exposure.equalize_adapthist(img, clip_limit=0.03)

    # Contrast stretching
    if choose == 'CS':
        p2 = np.percentile(img, 2)
        p98 = np.percentile(img, 98)
        img_new = exposure.rescale_intensity(img, in_range=(p2, p98))
        
    # Gamma contrast adjustment
    if choose == 'gamma':
        img_new = exposure.adjust_gamma(img, 2)
    
    # Log contrast adjustment
    if choose == 'log':
        img_new = exposure.adjust_log(img, 1)
        
    # Image Blurring - Averaging  - Note: n X n window. Smaller images will be blurred more
    if choose == 'blurr_avg':
        img_new = cv2.blur(img,(3,3))
        
    # Image Blurring - Gaussian  - Note: n X n window. Smaller images will be blurred more
    if choose == 'blurr_gaus':
        img_new = cv2.GaussianBlur(img,(5,5),0)

    # Image Blurring - Median Filtering 
    if choose == 'blurr_median':
        img_new = cv2.medianBlur(img,5)
        
    # Do nothing
    if choose == 'None':
        img_new = img
    
    # Convert back to 3D * if the image came in as 3d
    if img_is_3d == True:
        img_new = np.reshape(img_new, (img_new.shape[0], img_new.shape[1], 1)) 
    
    return img_new

#########################

# %% [markdown]
# ## (2) Load and Filter Data

# %%
# Load master index, and filter and assign to train and test using pandas

# Load prompt_id as text with leading zeros
df = pd.read_csv('../index_TORGO.txt', sep="|", converters={'prompt_id': lambda x: str(x)})
print('# rows in index file:', df.shape[0])

# (A) Remove instances where prompt is None OR prompts that begin with "[" or contain "jpg" OR where has_spect is No

df['remove'] = (df['prompt']==None) | (df['prompt']=='None') | (df['prompt'].str.contains('jpg')) | (df['prompt'].str.startswith('[')) | (df['has_spect']=='No')
df = df[df['remove']==False]
print('# rows with a prompt, and prompt does not contain [ or jpg:', df.shape[0])

# (B) Only keep instances where the recording was made on both the head and array mics

df_head = df[(df['mic']=='wav_headMic')]
df_array = df[(df['mic']=='wav_arrayMic')]

df_filter = pd.merge(df_head, df_array, on=['speaker','session','prompt_id'])
keep_id = df_filter['speaker'] + df_filter['session'] + df_filter['prompt_id']

df['keep_id'] = df['speaker'] + df['session'] + df['prompt_id']
df = df[df.keep_id.isin(keep_id)]
print('# rows with only prompts recorded on both mics:', df.shape[0]) 

# (C) Only keep instances where a prompt was recorded more than once

df_filter = df.groupby(['speaker','mic','prompt']).size().reset_index(name='counts')
df_filter = df_filter[df_filter['counts']>1]
keep_id = df_filter['speaker'] + df_filter['prompt']

df['keep_id'] = df['speaker'] + df['prompt']
df = df[df.keep_id.isin(keep_id)]
print('# rows with only prompts recorded more than once:', df.shape[0])
# Out:
# # rows in index file: 6179
# # rows with a prompt, and prompt does not contain [ or jpg: 5656
# # rows with only prompts recorded on both mics: 4942
# # rows with only prompts recorded more than once: 1422

# %%
df = df.sort_values(by=['speaker','prompt','prompt_id','mic'])
df.head(10)
# Out:
#     speaker   session           mic prompt_id has_spect spect_width  \
# 163     F01  Session1  wav_arrayMic      0030       yes         165
# 29      F01  Session1   wav_headMic      0030       yes         151
# 164     F01  Session1  wav_arrayMic      0031       yes         155
# 30      F01  Session1   wav_headMic      0031       yes         145
# 148     F01  Session1  wav_arrayMic      0015       yes          57
# 14      F01  Session1   wav_headMic      0015       yes          67
# 212     F01  Session1  wav_arrayMic      0079       yes          61
# 78      F01  Session1   wav_headMic      0079       yes          39
# 162     F01  Session1  wav_arrayMic      0029       yes          57
# 28      F01  Session1   wav_headMic      0029       yes          50
#
#     spect_height                                        prompt  remove  \
# 163          513  The quick brown fox jumps over the lazy dog.   False
# 29           513  The quick brown fox jumps over the lazy dog.   False
# 164          513  The quick brown fox jumps over the lazy dog.   False
# 30           513  The quick brown fox jumps over the lazy dog.   False
# 148          513                                           air   False
# 14           513                                           air   False
# 212          513                                           air   False
# 78           513                                           air   False
# 162          513                                          beat   False
# 28           513                                          beat   False
#
#                                              keep_id
# 163  F01The quick brown fox jumps over the lazy dog.
# 29   F01The quick brown fox jumps over the lazy dog.
# 164  F01The quick brown fox jumps over the lazy dog.
# 30   F01The quick brown fox jumps over the lazy dog.
# 148                                           F01air
# 14                                            F01air
# 212                                           F01air
# 78                                            F01air
# 162                                          F01beat
# 28                                           F01beat

# %% [markdown]
# ## (3) Assign Data to Test and Train Sets

# %%
# Using the head Mic data, Sort the df by speaker, prompt, and prompt id
# Alternate assigning each row to train and test
# Then use that to join the assignment to the main dataframe, in order to tag the array Mic data with train/test

df_filter = df[df['mic']=='wav_headMic'].sort_values(by=['speaker','prompt','prompt_id'])

df_filter['train'] = 0
train = 1
for index, row in df_filter.iterrows():
    df_filter.at[index,'train'] = train
    train *= -1

df_filter = df_filter[['speaker','session','prompt_id','train']]

df = pd.merge(df, df_filter, on=['speaker','session','prompt_id'])

# %%
# *** FOR NOW ONLY USE FEMALE 1 *** We can alter this later
df = df[df['speaker']=='F01']

# Add numerical prompt codes once final data set is compiled
df.prompt = pd.Categorical(df.prompt)
df['prompt_code'] = df.prompt.cat.codes

df.head(80)

num_classes = df['prompt_code'].max() + 1
print('Number of rows for Female 1:', df.shape[0])
print('Number of unique prompts for Female 1: ', num_classes)
df.head(80)
# Out:
# Number of rows for Female 1: 78
# Number of unique prompts for Female 1:  18
#    speaker   session           mic prompt_id has_spect spect_width  \
# 0      F01  Session1  wav_arrayMic      0030       yes         165
# 1      F01  Session1   wav_headMic      0030       yes         151
# 2      F01  Session1  wav_arrayMic      0031       yes         155
# 3      F01  Session1   wav_headMic      0031       yes         145
# 4      F01  Session1  wav_arrayMic      0015       yes          57
# 5      F01  Session1   wav_headMic      0015       yes          67
# 6      F01  Session1  wav_arrayMic      0079       yes          61
# 7      F01  Session1   wav_headMic      0079       yes          39
# 8      F01  Session1  wav_arrayMic      0029       yes          57
# 9      F01  Session1   wav_headMic      0029       yes          50
# 10     F01  Session1  wav_arrayMic      0054       yes          33
# 11     F01  Session1   wav_headMic      0054       yes          36
# 12     F01  Session1  wav_arrayMic      0101       yes          29
# 13     F01  Session1   wav_headMic      0101       yes          56
# 14     F01  Session1  wav_arrayMic      0102       yes          71
# 15     F01  Session1   wav_headMic      0102       yes          30
# 16     F01  Session1  wav_arrayMic      0027       yes         169
# 17     F01  Session1   wav_headMic      0027       yes         165
# 18     F01  Session1  wav_arrayMic      0028       yes         141
# 19     F01  Session1   wav_headMic      0028       yes         113
# 20     F01  Session1  wav_arrayMic      0046       yes          57
# 21     F01  Session1   wav_headMic      0046       yes          44
# 22     F01  Session1  wav_arrayMic      0073       yes          52
# 23     F01  Session1   wav_headMic      0073       yes          37
# 24     F01  Session1  wav_arrayMic      0115       yes          47
# 25     F01  Session1   wav_headMic      0115       yes          66
# 26     F01  Session1  wav_arrayMic      0117       yes          29
# 27     F01  Session1   wav_headMic      0117       yes          58
# 28     F01  Session1  wav_arrayMic      0025       yes          52
# 29     F01  Session1   wav_headMic      0025       yes          73
# ..     ...       ...           ...       ...       ...         ...
# 48     F01  Session1  wav_arrayMic      0043       yes          47
# 49     F01  Session1   wav_headMic      0043       yes          55
# 50     F01  Session1  wav_arrayMic      0062       yes          38
# 51     F01  Session1   wav_headMic      0062       yes          34
# 52     F01  Session1  wav_arrayMic      0085       yes          47
# 53     F01  Session1   wav_headMic      0085       yes          50
# 54     F01  Session1  wav_arrayMic      0019       yes          61
# 55     F01  Session1   wav_headMic      0019       yes          59
# 56     F01  Session1  wav_arrayMic      0128       yes          24
# 57     F01  Session1   wav_headMic      0128       yes          72
# 58     F01  Session1  wav_arrayMic      0129       yes          61
# 59     F01  Session1   wav_headMic      0129       yes          30
# 60     F01  Session1  wav_arrayMic      0016       yes          61
# 61     F01  Session1   wav_headMic      0016       yes          76
# 62     F01  Session1  wav_arrayMic      0053       yes          43
# 63     F01  Session1   wav_headMic      0053       yes          41
# 64     F01  Session1  wav_arrayMic      0058       yes          29
# 65     F01  Session1   wav_headMic      0058       yes          30
# 66     F01  Session1  wav_arrayMic      0059       yes          43
# 67     F01  Session1   wav_headMic      0059       yes          30
# 68     F01  Session1  wav_arrayMic      0075       yes          57
# 69     F01  Session1   wav_headMic      0075       yes          43
# 70     F01  Session1  wav_arrayMic      0110       yes          52
# 71     F01  Session1   wav_headMic      0110       yes          44
# 72     F01  Session1  wav_arrayMic      0104       yes         202
# 73     F01  Session1   wav_headMic      0104       yes         138
# 74     F01  Session1  wav_arrayMic      0105       yes         146
# 75     F01  Session1   wav_headMic      0105       yes         151
# 76     F01  Session1  wav_arrayMic      0106       yes         165
# 77     F01  Session1   wav_headMic      0106       yes         179
#
#    spect_height                                        prompt  remove  \
# 0           513  The quick brown fox jumps over the lazy dog.   False
# 1           513  The quick brown fox jumps over the lazy dog.   False
# 2           513  The quick brown fox jumps over the lazy dog.   False
# 3           513  The quick brown fox jumps over the lazy dog.   False
# 4           513                                           air   False
# 5           513                                           air   False
# 6           513                                           air   False
# 7           513                                           air   False
# 8           513                                          beat   False
# 9           513                                          beat   False
# 10          513                                          beat   False
# 11          513                                          beat   False
# 12          513                                           bug   False
# 13          513                                           bug   False
# 14          513                                           bug   False
# 15          513                                           bug   False
# 16          513            but he always answers, Banana oil!   False
# 17          513            but he always answers, Banana oil!   False
# 18          513            but he always answers, Banana oil!   False
# 19          513            but he always answers, Banana oil!   False
# 20          513                                         chair   False
# 21          513                                         chair   False
# 22          513                                         chair   False
# 23          513                                         chair   False
# 24          513                                          feed   False
# 25          513                                          feed   False
# 26          513                                          feed   False
# 27          513                                          feed   False
# 28          513                                          feet   False
# 29          513                                          feet   False
# ..          ...                                           ...     ...
# 48          513                                           sip   False
# 49          513                                           sip   False
# 50          513                                           sip   False
# 51          513                                           sip   False
# 52          513                                           sip   False
# 53          513                                           sip   False
# 54          513                                         storm   False
# 55          513                                         storm   False
# 56          513                                         storm   False
# 57          513                                         storm   False
# 58          513                                         storm   False
# 59          513                                         storm   False
# 60          513                                         swarm   False
# 61          513                                         swarm   False
# 62          513                                         swarm   False
# 63          513                                         swarm   False
# 64          513                                           the   False
# 65          513                                           the   False
# 66          513                                           the   False
# 67          513                                           the   False
# 68          513                                          warm   False
# 69          513                                          warm   False
# 70          513                                          warm   False
# 71          513                                          warm   False
# 72          513       yet he still thinks as swiftly as ever.   False
# 73          513       yet he still thinks as swiftly as ever.   False
# 74          513       yet he still thinks as swiftly as ever.   False
# 75          513       yet he still thinks as swiftly as ever.   False
# 76          513       yet he still thinks as swiftly as ever.   False
# 77          513       yet he still thinks as swiftly as ever.   False
#
#                                             keep_id  train  prompt_code
# 0   F01The quick brown fox jumps over the lazy dog.      1            0
# 1   F01The quick brown fox jumps over the lazy dog.      1            0
# 2   F01The quick brown fox jumps over the lazy dog.     -1            0
# 3   F01The quick brown fox jumps over the lazy dog.     -1            0
# 4                                            F01air      1            1
# 5                                            F01air      1            1
# 6                                            F01air     -1            1
# 7                                            F01air     -1            1
# 8                                           F01beat      1            2
# 9                                           F01beat      1            2
# 10                                          F01beat     -1            2
# 11                                          F01beat     -1            2
# 12                                           F01bug      1            3
# 13                                           F01bug      1            3
# 14                                           F01bug     -1            3
# 15                                           F01bug     -1            3
# 16            F01but he always answers, Banana oil!      1            4
# 17            F01but he always answers, Banana oil!      1            4
# 18            F01but he always answers, Banana oil!     -1            4
# 19            F01but he always answers, Banana oil!     -1            4
# 20                                         F01chair      1            5
# 21                                         F01chair      1            5
# 22                                         F01chair     -1            5
# 23                                         F01chair     -1            5
# 24                                          F01feed      1            6
# 25                                          F01feed      1            6
# 26                                          F01feed     -1            6
# 27                                          F01feed     -1            6
# 28                                          F01feet      1            7
# 29                                          F01feet      1            7
# ..                                              ...    ...          ...
# 48                                           F01sip      1           12
# 49                                           F01sip      1           12
# 50                                           F01sip     -1           12
# 51                                           F01sip     -1           12
# 52                                           F01sip      1           12
# 53                                           F01sip      1           12
# 54                                         F01storm     -1           13
# 55                                         F01storm     -1           13
# 56                                         F01storm      1           13
# 57                                         F01storm      1           13
# 58                                         F01storm     -1           13
# 59                                         F01storm     -1           13
# 60                                         F01swarm      1           14
# 61                                         F01swarm      1           14
# 62                                         F01swarm     -1           14
# 63                                         F01swarm     -1           14
# 64                                           F01the      1           15
# 65                                           F01the      1           15
# 66                                           F01the     -1           15
# 67                                           F01the     -1           15
# 68                                          F01warm      1           16
# 69                                          F01warm      1           16
# 70                                          F01warm     -1           16
# 71                                          F01warm     -1           16
# 72       F01yet he still thinks as swiftly as ever.      1           17
# 73       F01yet he still thinks as swiftly as ever.      1           17
# 74       F01yet he still thinks as swiftly as ever.     -1           17
# 75       F01yet he still thinks as swiftly as ever.     -1           17
# 76       F01yet he still thinks as swiftly as ever.      1           17
# 77       F01yet he still thinks as swiftly as ever.      1           17
#
# [78 rows x 12 columns]

# %% [markdown]
# ## (4) Resize All Images
#
# I initially tried padding the spectrogram images so that they were all squares and the same size...
#
# - I believe the CNN requires these images to be the same size. They are currently all the same height (frequency axis), but are not the same width (time axis). Therefore, we can pad the end of each image so that all of the images are also the same width using the max width of all the images. The CNN I set up requires the images to be squares, and dimensions should be an even number since they may be divided by two one or twice during the CNN. I set up the padding to pad the bottom of the y axis (frequency) with a replication of what is above it, that way the information is still useful for prediction, rather than just padding it with gray like the x axis (time) axis.
#
# However, I realized that this resulted in images that were too large, so I added the ability to resize/shrink the images...
#
# - This approach works better. I think we can ignore padding for now, and just resize the original images.
#
# [Tutorial for Padding with OpenCV](https://docs.opencv.org/3.1.0/d3/df2/tutorial_py_basic_ops.html)

# %%
# Get all predictor variables (images) and outcome variable (prompt), and train/test assignment
# Resize images

images_orig = []
images = []
prompts = []
train = []

maxwidth = image_height_width

for index, row in df.iterrows(): 
    #img_loc = '/'.join(['../data/TORGO', row['speaker'], row['session'], row['mic']+'_spect', row['prompt_id']+'.png'])
    img_loc = '/'.join(['../data/TORGO', row['speaker'], row['session'], row['mic']+'_mfcc', row['prompt_id']+'.png'])

    
    # Original image
    img = cv2.imread(img_loc, 0)
    images_orig.append(img) 
    
    # Resize image
    img = cv2.resize(img, (maxwidth, maxwidth))
    images.append(img)   
    
    prompts.append(row['prompt_code'])
    train.append(row['train'])
    
for i in images[0:2]:
    print('Shape:', i.shape)
# Out:
# Shape: (150, 150)
# Shape: (150, 150)

# %%
# View examples before and after re-size

cat = dict( enumerate(df['prompt'].cat.categories))  # Dictionary to look up prompt text from prompt code
num_examples = 4

fig = plt.figure(figsize=(16, 16))

for i in range(num_examples):
    plt.subplot(num_examples,2,2*i + 1),plt.imshow(images_orig[i*4]),plt.title(cat.get(prompts[i*4]))
    plt.subplot(num_examples,2,2*i + 2),plt.imshow(images[i*4])

# %% [markdown]
# ## (8) Set up and run CNN
#
# Simple model is based on [this](https://adventuresinmachinelearning.com/keras-tutorial-cnn-11-lines/)
#
# VGG model is based on [this](https://blogs.technet.microsoft.com/machinelearning/2018/01/30/hearing-ai-getting-started-with-deep-learning-for-audio-on-azure/)

# %%
# Split data into training and testing
x_train_pre = np.array([images[i] for i,x in enumerate(train) if x==1])
y_train_pre = np.array([prompts[i] for i,x in enumerate(train) if x==1])
x_test_pre = np.array([images[i] for i,x in enumerate(train) if x==-1])
y_test_pre = np.array([prompts[i] for i,x in enumerate(train) if x==-1])

x_train = x_train_pre
y_train = y_train_pre
x_test = x_test_pre
y_test = y_test_pre

print('Number of training records:', len(y_train))
print('Number of test records:', len(y_test))
# Out:
# Number of training records: 40
# Number of test records: 38

# %%
# input image dimensions
img_x, img_y = maxwidth, maxwidth

# %%
# reshape the data into a 4D tensor - (sample_number, x_img_size, y_img_size, num_channels)
# because it is in greyscale, we only have a single channel - RGB colour images would have 3
x_train = x_train.reshape(x_train.shape[0], img_x, img_y, 1)
x_test = x_test.reshape(x_test.shape[0], img_x, img_y, 1)
input_shape = (img_x, img_y, 1)

# %%
# convert the data to the right type
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (40, 150, 150, 1)
# 40 train samples
# 38 test samples

# %%
# convert class vectors to binary class matrices - this is for use in the
# categorical_crossentropy loss below
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
# "Simple" Network (This is not the VGG network)

model = Sequential()

# Convolution 1st layer
model.add(Conv2D(32, kernel_size=(5, 5), strides=(2, 2),
                 activation='relu',
                 padding = 'same',
                 input_shape=input_shape,
                 kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
#model.add(MaxPooling2D(pool_size=(2, 2)))

# Convolution 2nd layer
model.add(Conv2D(32, (3, 3), activation='relu', padding = 'same',
                kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
#model.add(MaxPooling2D(pool_size=(2, 2)))

# Convolution 3rd layer
model.add(Conv2D(32, (3, 3), activation='relu', padding = 'same',
                kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2)))

# Fully connected layer 1
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())

# # Fully connected layer 2
# model.add(Dense(100, activation='relu'))
# model.add(Dropout(0.2))
# model.add(BatchNormalization()) 

# Fully connected layer 3
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])

# %%
# # VGG based network

# model = Sequential()

# # section 1

# model.add(Convolution2D(filters=32, kernel_size=5,
#                         strides=2,
#                         padding="same",
#                         kernel_regularizer=l2(0.0001),
#                         kernel_initializer="normal",
#                         input_shape=input_shape))
# model.add(BatchNormalization())
# model.add(Activation('relu'))

# model.add(Convolution2D(filters=32, kernel_size=3,
#                         strides=1,
#                         padding="same",
#                         kernel_regularizer=l2(0.0001),
#                         kernel_initializer="normal"))
# model.add(BatchNormalization())
# model.add(Activation('relu'))

# model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Dropout(0.3))

# # section 2    
# model.add(Convolution2D(filters=64, kernel_size=3,
#                         strides=1,
#                         padding="same",
#                         kernel_regularizer=l2(0.0001),
#                         kernel_initializer="normal"))
# model.add(BatchNormalization())
# model.add(Activation('relu'))

# model.add(Convolution2D(filters=64, kernel_size=3,
#                         strides=1,
#                         padding="same",
#                         kernel_regularizer=l2(0.0001),
#                         kernel_initializer="normal"))
# model.add(BatchNormalization())
# model.add(Activation('relu'))

# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.3))

# # section 3
# model.add(Convolution2D(filters=128, kernel_size=3,
#                         strides=1,
#                         padding="same",
#                         kernel_regularizer=l2(0.0001),
#                         kernel_initializer="normal"))
# model.add(BatchNormalization())
# model.add(Activation('relu'))

# model.add(Convolution2D(filters=128, kernel_size=3,
#                         strides=1,
#                         padding="same",
#                         kernel_regularizer=l2(0.0001),
#                         kernel_initializer="normal"))
# model.add(BatchNormalization())
# model.add(Activation('relu'))

# model.add(Convolution2D(filters=128, kernel_size=3,
#                         strides=1,
#                         padding="same",
#                         kernel_regularizer=l2(0.0001),
#                         kernel_initializer="normal"))
# model.add(BatchNormalization())
# model.add(Activation('relu'))

# model.add(Convolution2D(filters=128, kernel_size=3,
#                         strides=1,
#                         padding="same",
#                         kernel_regularizer=l2(0.0001),
#                         kernel_initializer="normal"))
# model.add(BatchNormalization())
# model.add(Activation('relu'))

# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.3))

# # section 4
# model.add(Convolution2D(filters=512, kernel_size=3,
#                         strides=1,
#                         padding="valid",
#                         kernel_regularizer=l2(0.0001),
#                         kernel_initializer="normal"))
# model.add(BatchNormalization())
# model.add(Activation('relu'))
# model.add(Dropout(0.5))

# model.add(Convolution2D(filters=512, kernel_size=1,
#                         strides=1,
#                         padding="valid",
#                         kernel_regularizer=l2(0.0001),
#                         kernel_initializer="normal"))
# model.add(BatchNormalization())
# model.add(Activation('relu'))
# model.add(Dropout(0.5))

# # section 5
# model.add(Convolution2D(filters=num_classes, kernel_size=1,
#                         strides=1,
#                         padding="valid",
#                         kernel_regularizer=l2(0.0001),
#                         kernel_initializer="normal"))
# model.add(BatchNormalization())
# model.add(Activation('relu'))
# model.add(GlobalAveragePooling2D())

# model.add(Activation('softmax'))

# model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=Adamax(0.01))

# %%
class AccuracyHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.acc = []
        self.val_acc = []

    def on_epoch_end(self, batch, logs={}):
        self.acc.append(logs.get('acc'))
        self.val_acc.append(logs.get('val_acc'))

# %%
history = AccuracyHistory()

# %%
#datagen.fit(x_train)

# model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
#           steps_per_epoch=x_train.shape[0] // batch_size,
#           epochs=epochs,
#           validation_data=(x_test, y_test),
#           callbacks=[history])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test),
          callbacks=[history])

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 40 samples, validate on 38 samples
# Epoch 1/50
# 40/40 [==============================] - 3s 83ms/step - loss: 4.1141 - acc: 0.1000 - val_loss: 4.1561 - val_acc: 0.1842
# Epoch 2/50
# 40/40 [==============================] - 2s 43ms/step - loss: 1.9448 - acc: 0.6250 - val_loss: 3.3730 - val_acc: 0.1842
# Epoch 3/50
# 40/40 [==============================] - 2s 46ms/step - loss: 1.4560 - acc: 0.9000 - val_loss: 3.3399 - val_acc: 0.2368
# Epoch 4/50
# 40/40 [==============================] - 2s 48ms/step - loss: 1.1957 - acc: 0.9000 - val_loss: 3.3925 - val_acc: 0.2368
# Epoch 5/50
# 40/40 [==============================] - 2s 45ms/step - loss: 1.1181 - acc: 0.9500 - val_loss: 3.2848 - val_acc: 0.2632
# Epoch 6/50
# 40/40 [==============================] - 2s 47ms/step - loss: 0.9592 - acc: 1.0000 - val_loss: 3.2480 - val_acc: 0.2368
# Epoch 7/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.9404 - acc: 1.0000 - val_loss: 3.2240 - val_acc: 0.2105
# Epoch 8/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.8496 - acc: 1.0000 - val_loss: 3.2022 - val_acc: 0.2368
# Epoch 9/50
# 40/40 [==============================] - 2s 47ms/step - loss: 0.8372 - acc: 0.9750 - val_loss: 3.1793 - val_acc: 0.2368
# Epoch 10/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.7578 - acc: 1.0000 - val_loss: 3.1563 - val_acc: 0.2632
# Epoch 11/50
# 40/40 [==============================] - 2s 47ms/step - loss: 0.8234 - acc: 1.0000 - val_loss: 3.1323 - val_acc: 0.2895
# Epoch 12/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.7506 - acc: 1.0000 - val_loss: 3.1163 - val_acc: 0.2895
# Epoch 13/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.7137 - acc: 1.0000 - val_loss: 3.1014 - val_acc: 0.3158
# Epoch 14/50
# 40/40 [==============================] - 2s 46ms/step - loss: 0.7201 - acc: 1.0000 - val_loss: 3.0949 - val_acc: 0.2895
# Epoch 15/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.7335 - acc: 1.0000 - val_loss: 3.0902 - val_acc: 0.3158
# Epoch 16/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.6922 - acc: 1.0000 - val_loss: 3.0898 - val_acc: 0.3158
# Epoch 17/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.7006 - acc: 1.0000 - val_loss: 3.0923 - val_acc: 0.3158
# Epoch 18/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.6855 - acc: 1.0000 - val_loss: 3.0918 - val_acc: 0.3158
# Epoch 19/50
# 40/40 [==============================] - 2s 47ms/step - loss: 0.6721 - acc: 1.0000 - val_loss: 3.0914 - val_acc: 0.2895
# Epoch 20/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.6640 - acc: 1.0000 - val_loss: 3.0862 - val_acc: 0.2895
# Epoch 21/50
# 40/40 [==============================] - 2s 47ms/step - loss: 0.6710 - acc: 1.0000 - val_loss: 3.0811 - val_acc: 0.2895
# Epoch 22/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.6699 - acc: 1.0000 - val_loss: 3.0763 - val_acc: 0.2368
# Epoch 23/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.6425 - acc: 1.0000 - val_loss: 3.0788 - val_acc: 0.2368
# Epoch 24/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.6396 - acc: 1.0000 - val_loss: 3.0775 - val_acc: 0.2368
# Epoch 25/50
# 40/40 [==============================] - 2s 47ms/step - loss: 0.6388 - acc: 1.0000 - val_loss: 3.0737 - val_acc: 0.2368
# Epoch 26/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.6303 - acc: 1.0000 - val_loss: 3.0615 - val_acc: 0.2368
# Epoch 27/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.6282 - acc: 1.0000 - val_loss: 3.0512 - val_acc: 0.2368
# Epoch 28/50
# 40/40 [==============================] - 2s 47ms/step - loss: 0.6192 - acc: 1.0000 - val_loss: 3.0439 - val_acc: 0.2368
# Epoch 29/50
# 40/40 [==============================] - 2s 46ms/step - loss: 0.6059 - acc: 1.0000 - val_loss: 3.0310 - val_acc: 0.2368
# Epoch 30/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.6027 - acc: 1.0000 - val_loss: 3.0267 - val_acc: 0.2368
# Epoch 31/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.6059 - acc: 1.0000 - val_loss: 3.0139 - val_acc: 0.2368
# Epoch 32/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.5789 - acc: 1.0000 - val_loss: 2.9996 - val_acc: 0.2632
# Epoch 33/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.5918 - acc: 1.0000 - val_loss: 2.9923 - val_acc: 0.2632
# Epoch 34/50
# 40/40 [==============================] - 2s 44ms/step - loss: 0.5805 - acc: 1.0000 - val_loss: 2.9861 - val_acc: 0.2632
# Epoch 35/50
# 40/40 [==============================] - 2s 48ms/step - loss: 0.5780 - acc: 1.0000 - val_loss: 2.9817 - val_acc: 0.2632
# Epoch 36/50
# 40/40 [==============================] - 2s 47ms/step - loss: 0.5734 - acc: 1.0000 - val_loss: 2.9819 - val_acc: 0.2632
# Epoch 37/50
# 40/40 [==============================] - 2s 50ms/step - loss: 0.5600 - acc: 1.0000 - val_loss: 2.9782 - val_acc: 0.2632
# Epoch 38/50
# 40/40 [==============================] - 2s 48ms/step - loss: 0.5617 - acc: 1.0000 - val_loss: 2.9708 - val_acc: 0.2632
# Epoch 39/50
# 40/40 [==============================] - 2s 49ms/step - loss: 0.5649 - acc: 1.0000 - val_loss: 2.9671 - val_acc: 0.2632
# Epoch 40/50
# 40/40 [==============================] - 2s 48ms/step - loss: 0.5539 - acc: 1.0000 - val_loss: 2.9726 - val_acc: 0.2632
# Epoch 41/50
# 40/40 [==============================] - 2s 49ms/step - loss: 0.5511 - acc: 1.0000 - val_loss: 2.9830 - val_acc: 0.2895
# Epoch 42/50
# 40/40 [==============================] - 2s 46ms/step - loss: 0.5444 - acc: 1.0000 - val_loss: 2.9922 - val_acc: 0.2895
# Epoch 43/50
# 40/40 [==============================] - 2s 48ms/step - loss: 0.5406 - acc: 1.0000 - val_loss: 2.9945 - val_acc: 0.2895
# Epoch 44/50
# 40/40 [==============================] - 2s 48ms/step - loss: 0.5329 - acc: 1.0000 - val_loss: 2.9919 - val_acc: 0.2632
# Epoch 45/50
# 40/40 [==============================] - 2s 47ms/step - loss: 0.5253 - acc: 1.0000 - val_loss: 2.9912 - val_acc: 0.2632
# Epoch 46/50
# 40/40 [==============================] - 2s 47ms/step - loss: 0.5254 - acc: 1.0000 - val_loss: 2.9897 - val_acc: 0.2632
# Epoch 47/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.5106 - acc: 1.0000 - val_loss: 2.9841 - val_acc: 0.2632
# Epoch 48/50
# 40/40 [==============================] - 2s 48ms/step - loss: 0.5183 - acc: 1.0000 - val_loss: 2.9789 - val_acc: 0.2632
# Epoch 49/50
# 40/40 [==============================] - 2s 45ms/step - loss: 0.5057 - acc: 1.0000 - val_loss: 2.9826 - val_acc: 0.2632
# Epoch 50/50
# 40/40 [==============================] - 2s 46ms/step - loss: 0.5154 - acc: 1.0000 - val_loss: 2.9886 - val_acc: 0.2632
# Test loss: 2.988603453887136
# Test accuracy: 0.2631578978739287

# %%
plt.plot(range(1, epochs + 1), history.acc)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()
plt.plot(range(1, epochs + 1), history.val_acc)
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.show()
