# %% [markdown]
# # Download Files

# %% [markdown]
# Reference link: http://www.cs.toronto.edu/~complingweb/data/TORGO/torgo.html

# %%
# !wget -P data/TORGO http://www.cs.toronto.edu/~complingweb/data/TORGO/F.tar.bz2
# !wget -P data/TORGO http://www.cs.toronto.edu/~complingweb/data/TORGO/M.tar.bz2
# Out:
# --2019-01-23 18:53:49--  http://www.cs.toronto.edu/~complingweb/data/TORGO/F.tar.bz2
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1139746435 (1.1G) [application/x-bzip2]
# Saving to: ‘data/TORGO/F.tar.bz2’
#
# F.tar.bz2           100%[===================>]   1.06G  1.69MB/s    in 10m 5s
#
# 2019-01-23 19:03:54 (1.80 MB/s) - ‘data/TORGO/F.tar.bz2’ saved [1139746435/1139746435]
#
# --2019-01-23 19:03:54--  http://www.cs.toronto.edu/~complingweb/data/TORGO/M.tar.bz2
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2506634222 (2.3G) [application/x-bzip2]
# Saving to: ‘data/TORGO/M.tar.bz2’
#
# ...

# %%
# !tar xvjC data/TORGO -f data/TORGO/F.tar.bz2
# Out:
# F01/
# F01/Session1/
# F01/Session1/VIDEO
# F01/Session1/phn_arrayMic/
# F01/Session1/phn_arrayMic/0043.PHN
# F01/Session1/phn_arrayMic/0092.PHN
# F01/Session1/phn_arrayMic/0044.PHN
# F01/Session1/phn_arrayMic/0095.PHN
# F01/Session1/phn_arrayMic/0038.PHN
# F01/Session1/phn_arrayMic/0112.PHN
# F01/Session1/phn_arrayMic/0036.PHN
# F01/Session1/phn_arrayMic/0031.PHN
# F01/Session1/phn_arrayMic/0115.PHN
# F01/Session1/phn_arrayMic/0004.PHN
# F01/Session1/phn_arrayMic/0120.PHN
# F01/Session1/phn_arrayMic/0078.PHN
# F01/Session1/phn_arrayMic/0127.PHN
# F01/Session1/phn_arrayMic/0003.PHN
# F01/Session1/phn_arrayMic/0129.PHN
# F01/Session1/phn_arrayMic/0071.PHN
# F01/Session1/phn_arrayMic/0076.PHN
# F01/Session1/phn_arrayMic/0067.PHN
# F01/Session1/phn_arrayMic/0060.PHN
# F01/Session1/phn_arrayMic/0012.PHN
# F01/Session1/phn_arrayMic/0015.PHN
# F01/Session1/phn_arrayMic/0069.PHN
# F01/Session1/phn_arrayMic/0131.PHN
# F01/Session1/phn_arrayMic/0020.PHN
# F01/Session1/phn_arrayMic/0104.PHN
# ...

# %%
# !tar xvjC data/TORGO -f data/TORGO/M.tar.bz2
# Out:
# M01/
# M01/Notes/
# M01/Notes/M01.csv
# M01/Notes/Analysis of M01 transcribte data 1-100.doc
# M01/Session2_3/
# M01/Session2_3/alignment.txt
# M01/Session2_3/phn_arrayMic/
# M01/Session2_3/phn_arrayMic/0249.PHN
# M01/Session2_3/phn_arrayMic/0006.PHN
# M01/Session2_3/phn_arrayMic/0122.PHN
# M01/Session2_3/phn_arrayMic/0235.PHN
# M01/Session2_3/phn_arrayMic/0125.PHN
# M01/Session2_3/phn_arrayMic/0232.PHN
# M01/Session2_3/phn_arrayMic/0188.PHN
# M01/Session2_3/phn_arrayMic/0001.PHN
# M01/Session2_3/phn_arrayMic/0073.PHN
# M01/Session2_3/phn_arrayMic/0157.PHN
# M01/Session2_3/phn_arrayMic/0186.PHN
# M01/Session2_3/phn_arrayMic/0240.PHN
# M01/Session2_3/phn_arrayMic/0150.PHN
# M01/Session2_3/phn_arrayMic/0181.PHN
# M01/Session2_3/phn_arrayMic/0247.PHN
# M01/Session2_3/phn_arrayMic/0008.PHN
# M01/Session2_3/phn_arrayMic/0074.PHN
# M01/Session2_3/phn_arrayMic/0272.PHN
# M01/Session2_3/phn_arrayMic/0165.PHN
# M01/Session2_3/phn_arrayMic/0119.PHN
# M01/Session2_3/phn_arrayMic/0041.PHN
# ...
